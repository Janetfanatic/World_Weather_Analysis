# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 623

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather['name'])


        try:
            # Parse out the needed data.
            city_rain = city_weather["rain"]["1h"]
        except: 
            city_rain = 0.0

        try:
            city_snow = city_snow['snow']['1h']
        except:
            city_snow = 0.0

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]


        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})
    except:
        print("city not found")
        
# If a Keyerror is experienced, add 0 to the column.
    
    #except (KeyError):
     #   city_data["Rain (inches)", "Snow (inches)"] = [0]

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 24 of Set 13 | tsiroanomandidy
# Tsiroanomandidy
# Processing Record 25 of Set 13 | nikolskoye
# Nikolskoye
# Processing Record 26 of Set 13 | dzerzhinskoye
# Dzerzhinskoye
# Processing Record 27 of Set 13 | labutta
# city not found
# Processing Record 28 of Set 13 | vieste
# Vieste
# Processing Record 29 of Set 13 | kormilovka
# Kormilovka
# Processing Record 30 of Set 13 | inhambane
# Inhambane
# Processing Record 31 of Set 13 | hobart
# Hobart
# Processing Record 32 of Set 13 | hofn
# Hofn
# Processing Record 33 of Set 13 | thompson
# Thompson
# Processing Record 34 of Set 13 | atuona
# Atuona
# Processing Record 35 of Set 13 | port alfred
# Port Alfred
# Processing Record 36 of Set 13 | kahului
# Kahului
# Processing Record 37 of Set 13 | cape town
# Cape Town
# Processing Record 38 of Set 13 | saskylakh
# Saskylakh
# Processing Record 39 of Set 13 | albany
# Albany
# Processing Record 40 of Set 13 | rikitea
# Rikitea
# Processing Record 41 of Set 13 | parana
# Paraná
# Processing Record 42 of Set 13 | bredasdorp
# Bredasdorp
# Processing Record 43 of Set 13 | narsaq
# Narsaq
# Processing Record 44 of Set 13 | puerto ayora
# Puerto Ayora
# Processing Record 45 of Set 13 | mataura
# Mataura
# Processing Record 46 of Set 13 | pangody
# Pangody
# Processing Record 47 of Set 13 | gat
# Kiryat Gat
# Processing Record 48 of Set 13 | yellowknife
# Yellowknife
# Processing Record 49 of Set 13 | rancho palos verdes
# Rancho Palos Verdes
# Processing Record 50 of Set 13 | bluff
# Bluff
# Processing Record 51 of Set 13 | ponta do sol
# Ponta do Sol
# Processing Record 52 of Set 13 | obo
# Obo
# Processing Record 53 of Set 13 | port hardy
# Port Hardy
# Processing Record 54 of Set 13 | ushuaia
# Ushuaia
# Processing Record 55 of Set 13 | vostok
# Vostok
# Processing Record 56 of Set 13 | sembe
# Sémbé
# Processing Record 57 of Set 13 | bambous virieux
# Bambous Virieux
# Processing Record 58 of Set 13 | severo-kurilsk
# Severo-Kuril'sk
# Processing Record 59 of Set 13 | katsuura
# Katsuura
# Processing Record 60 of Set 13 | tasiilaq
# Tasiilaq
# Processing Record 61 of Set 13 | coihaique
# Coyhaique
# Processing Record 62 of Set 13 | akusha
# Akusha
# Processing Record 63 of Set 13 | new norfolk
# New Norfolk
# Processing Record 64 of Set 13 | salalah
# Salalah
# Processing Record 65 of Set 13 | amarante do maranhao
# Amarante do Maranhão
# Processing Record 66 of Set 13 | vardo
# Vardø
# Processing Record 67 of Set 13 | manado
# Manado
# Processing Record 68 of Set 13 | dingle
# Dingle
# Processing Record 69 of Set 13 | puerto escondido
# Puerto Escondido
# Processing Record 70 of Set 13 | khatanga
# Khatanga
# Processing Record 71 of Set 13 | tabou
# Tabou
# Processing Record 72 of Set 13 | arraial do cabo
# Arraial do Cabo
# Processing Record 73 of Set 13 | poum
# Poum
# Processing Record 1 of Set 14 | provideniya
# Provideniya
# Processing Record 2 of Set 14 | hilo
# Hilo
# Processing Record 3 of Set 14 | quesnel
# Quesnel
# Processing Record 4 of Set 14 | vaini
# Vaini
# Processing Record 5 of Set 14 | taolanaro
# city not found
# Processing Record 6 of Set 14 | lata
# Lata
# Processing Record 7 of Set 14 | kapaa
# Kapaa
# Processing Record 8 of Set 14 | berlevag
# Berlevåg
# Processing Record 9 of Set 14 | yichun
# Yichun
# Processing Record 10 of Set 14 | hamilton
# Hamilton
# Processing Record 11 of Set 14 | qaqortoq
# Qaqortoq
# Processing Record 12 of Set 14 | asilah
# Asilah
# Processing Record 13 of Set 14 | portland
# Portland
# Processing Record 14 of Set 14 | bathsheba
# Bathsheba
# Processing Record 15 of Set 14 | aklavik
# Aklavik
# Processing Record 16 of Set 14 | punta arenas
# Punta Arenas
# Processing Record 17 of Set 14 | todos santos
# Todos Santos
# Processing Record 18 of Set 14 | san cristobal
# San Cristobal
# Processing Record 19 of Set 14 | kavieng
# Kavieng
# Processing Record 20 of Set 14 | tiksi
# Tiksi
# Processing Record 21 of Set 14 | tumannyy
# city not found
# Processing Record 22 of Set 14 | kodiak
# Saint Paul Harbor
# Processing Record 23 of Set 14 | barentsburg
# city not found
# Processing Record 24 of Set 14 | price
# Price
# Processing Record 25 of Set 14 | barrow
# Barrow
# Processing Record 26 of Set 14 | ahipara
# Ahipara
# Processing Record 27 of Set 14 | antsohihy
# Antsohihy
# Processing Record 28 of Set 14 | gondanglegi
# Gondanglegi
# Processing Record 29 of Set 14 | qaanaaq
# Qaanaaq
# Processing Record 30 of Set 14 | pervomayskiy
# Pervomayskiy
# Processing Record 31 of Set 14 | port-gentil
# Port-Gentil
# Processing Record 32 of Set 14 | victoria
# Hong Kong
# Processing Record 33 of Set 14 | iqaluit
# Iqaluit
# Processing Record 34 of Set 14 | faanui
# Faanui
# Processing Record 35 of Set 14 | mar del plata
# Mar del Plata
# Processing Record 36 of Set 14 | busselton
# Busselton
# Processing Record 37 of Set 14 | tautira
# Tautira
# Processing Record 38 of Set 14 | sentyabrskiy
# city not found
# Processing Record 39 of Set 14 | torbay
# Torbay
# Processing Record 40 of Set 14 | callaguip
# Callaguip
# Processing Record 41 of Set 14 | kurmanayevka
# Kurmanayevka
# Processing Record 42 of Set 14 | osorno
# Osorno
# Processing Record 43 of Set 14 | lunenburg
# Lunenburg
# Processing Record 44 of Set 14 | kysyl-syr
# Kysyl-Syr
# Processing Record 45 of Set 14 | koslan
# Koslan
# Processing Record 46 of Set 14 | tsihombe
# city not found
# Processing Record 47 of Set 14 | chagda
# city not found
# Processing Record 48 of Set 14 | hithadhoo
# Hithadhoo
# Processing Record 49 of Set 14 | illoqqortoormiut
# city not found
# Processing Record 50 of Set 14 | ust-omchug
# Ust'-Omchug
# Processing Record 1 of Set 15 | bolshoy tsaryn
# city not found
# Processing Record 2 of Set 15 | ballitoville
# Ballitoville
# Processing Record 3 of Set 15 | san quintin
# San Quintín
# Processing Record 4 of Set 15 | port elizabeth
# Port Elizabeth
# Processing Record 5 of Set 15 | sao filipe
# São Filipe
# Processing Record 6 of Set 15 | roald
# Roald
# Processing Record 7 of Set 15 | jamestown
# Jamestown
# Processing Record 8 of Set 15 | shatrovo
# Shatrovo
# Processing Record 9 of Set 15 | hof
# Hof
# Processing Record 10 of Set 15 | mehamn
# Mehamn
# Processing Record 11 of Set 15 | davila
# Davila
# Processing Record 12 of Set 15 | marcona
# city not found
# Processing Record 13 of Set 15 | tromso
# Tromsø
# Processing Record 14 of Set 15 | mys shmidta
# city not found
# Processing Record 15 of Set 15 | lagoa
# Lagoa
# Processing Record 16 of Set 15 | lompoc
# Lompoc
# Processing Record 17 of Set 15 | chibuto
# Chibuto
# Processing Record 18 of Set 15 | yarkovo
# Yarkovo
# Processing Record 19 of Set 15 | tuatapere
# Tuatapere
# Processing Record 20 of Set 15 | serrai
# city not found
# Processing Record 21 of Set 15 | ratnagiri
# Ratnagiri
# Processing Record 22 of Set 15 | nizhneyansk
# city not found
# Processing Record 23 of Set 15 | hermanus
# Hermanus
# Processing Record 24 of Set 15 | bethel
# Bethel
# Processing Record 25 of Set 15 | saint-pierre
# Saint-Pierre
# Processing Record 26 of Set 15 | cabo san lucas
# Cabo San Lucas
# Processing Record 27 of Set 15 | lukovetskiy
# Lukovetskiy
# Processing Record 28 of Set 15 | canutama
# Canutama
# Processing Record 29 of Set 15 | luganville
# Luganville
# Processing Record 30 of Set 15 | geraldton
# Geraldton
# Processing Record 31 of Set 15 | vila velha
# Vila Velha
# Processing Record 32 of Set 15 | attawapiskat
# city not found
# Processing Record 33 of Set 15 | east london
# East London
# Processing Record 34 of Set 15 | belushya guba
# city not found
# Processing Record 35 of Set 15 | hervey bay
# Hervey Bay
# Processing Record 36 of Set 15 | skelleftea
# Skellefteå
# Processing Record 37 of Set 15 | ranong
# Ranong
# Processing Record 38 of Set 15 | butaritari
# Butaritari
# Processing Record 39 of Set 15 | colon
# Colón
# Processing Record 40 of Set 15 | esperance
# Esperance
# Processing Record 41 of Set 15 | sulangan
# Sulangan
# Processing Record 42 of Set 15 | luderitz
# Lüderitz
# Processing Record 43 of Set 15 | chase
# Chase
# Processing Record 44 of Set 15 | itarema
# Itarema
# Processing Record 45 of Set 15 | nuevo progreso
# Nuevo Progreso
# Processing Record 46 of Set 15 | san patricio
# San Patricio
# Processing Record 47 of Set 15 | dudinka
# Dudinka
# Processing Record 48 of Set 15 | durango
# Durango
# Processing Record 49 of Set 15 | korhogo
# Korhogo
# Processing Record 50 of Set 15 | shimoda
# Shimoda
# Processing Record 1 of Set 16 | gornyy
# Gornyy
# Processing Record 2 of Set 16 | atasu
# Atasū
# Processing Record 3 of Set 16 | linqiong
# Linqiong
# Processing Record 4 of Set 16 | coahuayana
# Coahuayana Viejo
# Processing Record 5 of Set 16 | tabuk
# Tabuk
# Processing Record 6 of Set 16 | saldanha
# Saldanha
# Processing Record 7 of Set 16 | tres rios
# Três Rios
# Processing Record 8 of Set 16 | ilo
# Ilo
# Processing Record 9 of Set 16 | ancud
# Ancud
# Processing Record 10 of Set 16 | lao cai
# Lao Cai
# Processing Record 11 of Set 16 | san carlos del zulia
# San Carlos del Zulia
# Processing Record 12 of Set 16 | carnarvon
# Carnarvon
# Processing Record 13 of Set 16 | champerico
# Champerico
# Processing Record 14 of Set 16 | okha
# Okha
# Processing Record 15 of Set 16 | wajima
# Wajima
# Processing Record 16 of Set 16 | sabang
# Sabang
# Processing Record 17 of Set 16 | kampong thum
# Kampong Thom
# Processing Record 18 of Set 16 | palabuhanratu
# city not found
# Processing Record 19 of Set 16 | kenai
# Kenai
# Processing Record 20 of Set 16 | avarua
# Avarua
# Processing Record 21 of Set 16 | powell river
# Powell River
# Processing Record 22 of Set 16 | murmino
# Murmino
# Processing Record 23 of Set 16 | alice springs
# Alice Springs
# Processing Record 24 of Set 16 | monte cristi
# city not found
# Processing Record 25 of Set 16 | port macquarie
# Port Macquarie
# Processing Record 26 of Set 16 | touros
# Touros
# Processing Record 27 of Set 16 | sulphur
# Sulphur
# Processing Record 28 of Set 16 | ormara
# Ormara
# Processing Record 29 of Set 16 | semnan
# Semnan
# Processing Record 30 of Set 16 | schortens
# Schortens
# Processing Record 31 of Set 16 | jieshi
# Jieshi
# Processing Record 32 of Set 16 | nemuro
# Nemuro
# Processing Record 33 of Set 16 | paucartambo
# city not found
# Processing Record 34 of Set 16 | kiunga
# Kiunga
# Processing Record 35 of Set 16 | colares
# Colares
# Processing Record 36 of Set 16 | maragogi
# Maragogi
# Processing Record 37 of Set 16 | pangnirtung
# Pangnirtung
# Processing Record 38 of Set 16 | coquimbo
# Coquimbo
# Processing Record 39 of Set 16 | pacific grove
# Pacific Grove
# Processing Record 40 of Set 16 | antofagasta
# Antofagasta
# Processing Record 41 of Set 16 | samusu
# city not found
# Processing Record 42 of Set 16 | hornepayne
# Hornepayne
# Processing Record 43 of Set 16 | nioro
# Nioro
# Processing Record 44 of Set 16 | paidha
# Paidha
# Processing Record 45 of Set 16 | tual
# Tual
# Processing Record 46 of Set 16 | gijon
# Gijón
# Processing Record 47 of Set 16 | kruisfontein
# Kruisfontein
# Processing Record 48 of Set 16 | svetlogorsk
# Forsytheganj
# Processing Record 49 of Set 16 | georgetown
# George Town
# Processing Record 50 of Set 16 | dikson
# Dikson
# Processing Record 1 of Set 17 | beloha
# Beloha
# Processing Record 2 of Set 17 | pisco
# Pisco
# Processing Record 3 of Set 17 | chapais
# Chapais
# Processing Record 4 of Set 17 | athabasca
# Athabasca
# Processing Record 5 of Set 17 | sitka
# Sitka
# Processing Record 6 of Set 17 | sobolevo
# Sobolevo
# Processing Record 7 of Set 17 | el real de santa maria
# El Real de Santa Maria
# Processing Record 8 of Set 17 | upernavik
# Upernavik
# Processing Record 9 of Set 17 | vaitupu
# city not found
# Processing Record 10 of Set 17 | gizo
# Gizo Government Station
# Processing Record 11 of Set 17 | saquena
# Saquena
# Processing Record 12 of Set 17 | castro
# Castro
# Processing Record 13 of Set 17 | broome
# Broome
# Processing Record 14 of Set 17 | dese
# Dessie
# Processing Record 15 of Set 17 | jalu
# Jalu
# Processing Record 16 of Set 17 | rundu
# Rundu
# Processing Record 17 of Set 17 | cairns
# Cairns
# Processing Record 18 of Set 17 | chengde
# Chengde
# Processing Record 19 of Set 17 | khartoum
# Khartoum
# Processing Record 20 of Set 17 | lavrentiya
# Lavrentiya
# Processing Record 21 of Set 17 | havoysund
# Havøysund
# Processing Record 22 of Set 17 | viedma
# Viedma
# Processing Record 23 of Set 17 | bandarbeyla
# Bandarbeyla
# Processing Record 24 of Set 17 | pevek
# Pevek
# Processing Record 25 of Set 17 | tuktoyaktuk
# Tuktoyaktuk
# Processing Record 26 of Set 17 | mount gambier
# Mount Gambier
# Processing Record 27 of Set 17 | cravo norte
# Cravo Norte
# Processing Record 28 of Set 17 | amderma
# city not found
# Processing Record 29 of Set 17 | nanortalik
# Nanortalik
# Processing Record 30 of Set 17 | abu samrah
# Abu Samrah
# Processing Record 31 of Set 17 | kushima
# Kushima
# Processing Record 32 of Set 17 | ketchikan
# Ketchikan
# Processing Record 33 of Set 17 | broken hill
# Broken Hill
# Processing Record 34 of Set 17 | souillac
# Souillac
# Processing Record 35 of Set 17 | saint-philippe
# Saint-Philippe
# Processing Record 36 of Set 17 | atar
# Atar
# Processing Record 37 of Set 17 | gunupur
# Gunupur
# Processing Record 38 of Set 17 | elmina
# Elmina
# Processing Record 39 of Set 17 | kisangani
# Kisangani
# Processing Record 40 of Set 17 | vezirkopru
# Vezirköprü
# Processing Record 41 of Set 17 | ilulissat
# Ilulissat
# Processing Record 42 of Set 17 | te anau
# Te Anau
# Processing Record 43 of Set 17 | camacha
# Camacha
# Processing Record 44 of Set 17 | igarka
# Igarka
# Processing Record 45 of Set 17 | bonavista
# Bonavista
# Processing Record 46 of Set 17 | tessalit
# Tessalit
# Processing Record 47 of Set 17 | padang
# Padang
# Processing Record 48 of Set 17 | carlton
# Carlton
# Processing Record 49 of Set 17 | itoman
# Itoman
# Processing Record 50 of Set 17 | cidreira
# Cidreira
# Processing Record 1 of Set 18 | anadyr
# Anadyr
# Processing Record 2 of Set 18 | kaitangata
# Kaitangata
# Processing Record 3 of Set 18 | belmonte
# Belmonte
# Processing Record 4 of Set 18 | kramat
# Kramat
# Processing Record 5 of Set 18 | socorro
# Socorro
# Processing Record 6 of Set 18 | zhangjiakou
# Zhangjiakou
# Processing Record 7 of Set 18 | tyrma
# Tyrma
# Processing Record 8 of Set 18 | nata
# Natá
# Processing Record 9 of Set 18 | pahrump
# Pahrump
# Processing Record 10 of Set 18 | bengkulu
# Bengkulu
# Processing Record 11 of Set 18 | serra talhada
# Serra Talhada
# Processing Record 12 of Set 18 | el wasta
# city not found
# Processing Record 13 of Set 18 | kashan
# Kashan
# Processing Record 14 of Set 18 | batagay-alyta
# Batagay-Alyta
# Processing Record 15 of Set 18 | margate
# Margate
# Processing Record 16 of Set 18 | teguldet
# Tegul'det
# Processing Record 17 of Set 18 | boa vista
# Boa Vista
# Processing Record 18 of Set 18 | port blair
# Port Blair
# Processing Record 19 of Set 18 | grand river south east
# city not found
# Processing Record 20 of Set 18 | nkhotakota
# Nkhotakota
# Processing Record 21 of Set 18 | pyu
# Pyu
# Processing Record 22 of Set 18 | mahebourg
# Mahébourg
# Processing Record 23 of Set 18 | nakasongola
# Nakasongola
# Processing Record 24 of Set 18 | fare
# Fare
# Processing Record 25 of Set 18 | ivrea
# Ivrea
# Processing Record 26 of Set 18 | nueva loja
# Nueva Loja
# Processing Record 27 of Set 18 | moose factory
# Moose Factory
# Processing Record 28 of Set 18 | farah
# Farah
# Processing Record 29 of Set 18 | longyearbyen
# Longyearbyen
# Processing Record 30 of Set 18 | avera
# Avera
# Processing Record 31 of Set 18 | arkhipo-osipovka
# Arkhipo-Osipovka
# Processing Record 32 of Set 18 | do gonbadan
# Gachsaran
# Processing Record 33 of Set 18 | seia
# Seia
# Processing Record 34 of Set 18 | sayyan
# Sayyan
# Processing Record 35 of Set 18 | northam
# Northam
# Processing Record 36 of Set 18 | horadiz
# Horadiz
# Processing Record 37 of Set 18 | luang prabang
# Luang Prabang
# Processing Record 38 of Set 18 | ulaanbaatar
# Ulaanbaatar
# Processing Record 39 of Set 18 | fayaoue
# Fayaoué
# Processing Record 40 of Set 18 | sinaloa
# Sinaloa
# Processing Record 41 of Set 18 | bonanza
# Bonanza
# Processing Record 42 of Set 18 | berdigestyakh
# Berdigestyakh
# Processing Record 43 of Set 18 | leningradskiy
# Leningradskiy
# Processing Record 44 of Set 18 | airai
# Airai
# Processing Record 45 of Set 18 | grindavik
# Grindavik
# Processing Record 46 of Set 18 | roma
# Rome
# Processing Record 47 of Set 18 | novoseleznevo
# Novoseleznëvo
# Processing Record 48 of Set 18 | dawei
# Dawei
# Processing Record 49 of Set 18 | vallenar
# Vallenar
# Processing Record 50 of Set 18 | sibolga
# Sibolga
# Processing Record 1 of Set 19 | juneau
# Juneau
# Processing Record 2 of Set 19 | saleaula
# city not found
# Processing Record 3 of Set 19 | halalo
# city not found
# Processing Record 4 of Set 19 | ranfurly
# Ranfurly
# Processing Record 5 of Set 19 | ust-maya
# Ust-Maya
# Processing Record 6 of Set 19 | cedar city
# Cedar City
# Processing Record 7 of Set 19 | chokurdakh
# Chokurdakh
# Processing Record 8 of Set 19 | huazolotitlan
# city not found
# Processing Record 9 of Set 19 | champasak
# Champasak
# Processing Record 10 of Set 19 | esso
# Esso
# Processing Record 11 of Set 19 | qasigiannguit
# Qasigiannguit
# Processing Record 12 of Set 19 | necochea
# Necochea
# Processing Record 13 of Set 19 | khandyga
# Khandyga
# Processing Record 14 of Set 19 | caluquembe
# Caluquembe
# Processing Record 15 of Set 19 | sur
# Sur
# Processing Record 16 of Set 19 | korla
# Korla
# Processing Record 17 of Set 19 | springdale
# Springdale
# Processing Record 18 of Set 19 | mandan
# Mandan
# Processing Record 19 of Set 19 | buala
# Buala
# Processing Record 20 of Set 19 | kawalu
# Kawalu
# Processing Record 21 of Set 19 | kibala
# Kibala
# Processing Record 22 of Set 19 | alta floresta
# Alta Floresta
# Processing Record 23 of Set 19 | kokopo
# Kokopo
# Processing Record 24 of Set 19 | vila
# Vila
# Processing Record 25 of Set 19 | tchaourou
# Tchaourou
# Processing Record 26 of Set 19 | kinango
# Kinango
# Processing Record 27 of Set 19 | sept-iles
# Sept-Îles
# Processing Record 28 of Set 19 | alofi
# Alofi
# Processing Record 29 of Set 19 | yeletskiy
# city not found
# Processing Record 30 of Set 19 | tevriz
# Tevriz
# Processing Record 31 of Set 19 | kavaratti
# Kavaratti
# Processing Record 32 of Set 19 | meyungs
# city not found
# Processing Record 33 of Set 19 | hovd
# Khovd
# Processing Record 34 of Set 19 | college
# College
# Processing Record 35 of Set 19 | caravelas
# Caravelas
# Processing Record 36 of Set 19 | manzhouli
# Manzhouli
# Processing Record 37 of Set 19 | salinopolis
# Salinópolis
# Processing Record 38 of Set 19 | saint stephen
# Saint Stephen
# Processing Record 39 of Set 19 | quatre cocos
# Quatre Cocos
# Processing Record 40 of Set 19 | chingirlau
# Chingirlau
# Processing Record 41 of Set 19 | honningsvag
# Honningsvåg
# Processing Record 42 of Set 19 | wahpeton
# Wahpeton
# Processing Record 43 of Set 19 | morgan city
# Morgan City
# Processing Record 44 of Set 19 | waipawa
# Waipawa
# Processing Record 45 of Set 19 | yeppoon
# Yeppoon
# Processing Record 46 of Set 19 | portsmouth
# Portsmouth
# Processing Record 47 of Set 19 | liku
# Liku
# Processing Record 48 of Set 19 | toulepleu
# city not found
# Processing Record 49 of Set 19 | kieta
# Kieta
# Processing Record 50 of Set 19 | osypenko
# Osypenko
# Processing Record 1 of Set 20 | marsala
# Marsala
# Processing Record 2 of Set 20 | nantucket
# Nantucket
# Processing Record 3 of Set 20 | douentza
# Douentza
# Processing Record 4 of Set 20 | hobyo
# Hobyo
# Processing Record 5 of Set 20 | dasoguz
# Daşoguz
# Processing Record 6 of Set 20 | sabha
# Sabha
# Processing Record 7 of Set 20 | sompeta
# Sompeta
# Processing Record 8 of Set 20 | bururi
# Bururi Province
# Processing Record 9 of Set 20 | hirara
# Hirara
# Processing Record 10 of Set 20 | balykshi
# city not found
# Processing Record 11 of Set 20 | hihifo
# city not found
# Processing Record 12 of Set 20 | burica
# city not found
# Processing Record 13 of Set 20 | bud
# Bud
# Processing Record 14 of Set 20 | ngukurr
# city not found
# Processing Record 15 of Set 20 | makakilo city
# Makakilo City
# Processing Record 16 of Set 20 | kyenjojo
# Kyenjojo
# Processing Record 17 of Set 20 | dukat
# Dukat
# Processing Record 18 of Set 20 | fuzhou
# Fuzhou
# Processing Record 19 of Set 20 | pandaria
# Pandaria
# Processing Record 20 of Set 20 | miri
# Marabu
# Processing Record 21 of Set 20 | leshukonskoye
# Leshukonskoye
# Processing Record 22 of Set 20 | warqla
# city not found
# Processing Record 23 of Set 20 | virginia beach
# Virginia Beach
# Processing Record 24 of Set 20 | pangkalanbuun
# Pangkalanbuun
# Processing Record 25 of Set 20 | pierre
# Pierre
# Processing Record 26 of Set 20 | barawe
# city not found
# Processing Record 27 of Set 20 | tivoli
# Tivoli
# Processing Record 28 of Set 20 | tazovskiy
# Tazovsky
# Processing Record 29 of Set 20 | carutapera
# Carutapera
# Processing Record 30 of Set 20 | sisimiut
# Sisimiut
# Processing Record 31 of Set 20 | osoyoos
# Osoyoos
# Processing Record 32 of Set 20 | kirkwood
# Kirkwood
# Processing Record 33 of Set 20 | changtu
# Changtu
# Processing Record 34 of Set 20 | kralendijk
# Kralendijk
# Processing Record 35 of Set 20 | mmabatho
# Mmabatho
# Processing Record 36 of Set 20 | saint-joseph
# Saint-Joseph
# Processing Record 37 of Set 20 | vao
# Vao
# Processing Record 38 of Set 20 | birao
# Birao
# Processing Record 39 of Set 20 | san andres
# San Andrés
# Processing Record 40 of Set 20 | harper
# Harper
# Processing Record 41 of Set 20 | yumen
# Yumen
# Processing Record 42 of Set 20 | tura
# Tura
# Processing Record 43 of Set 20 | banswada
# Bānswāda
# Processing Record 44 of Set 20 | balkanabat
# Balkanabat
# Processing Record 45 of Set 20 | semey
# Semey
# Processing Record 46 of Set 20 | harrison
# Harrison
# Processing Record 47 of Set 20 | mezhdurechenskiy
# Mezhdurechenskiy
# Processing Record 48 of Set 20 | kampene
# Kampene
# Processing Record 49 of Set 20 | bur gabo
# city not found
# Processing Record 50 of Set 20 | yining
# Yining
# Processing Record 1 of Set 21 | garowe
# Garoowe
# Processing Record 2 of Set 21 | loreto
# Loreto
# Processing Record 3 of Set 21 | crotone
# Crotone
# Processing Record 4 of Set 21 | aksarka
# Aksarka
# Processing Record 5 of Set 21 | nurota
# Nurota
# Processing Record 6 of Set 21 | wamba
# Wamba
# Processing Record 7 of Set 21 | eydhafushi
# Eydhafushi
# Processing Record 8 of Set 21 | prainha
# Prainha
# Processing Record 9 of Set 21 | hailar
# Hailar
# Processing Record 10 of Set 21 | namtsy
# Namtsy
# Processing Record 11 of Set 21 | ribeira grande
# Ribeira Grande
# Processing Record 12 of Set 21 | zhigansk
# Zhigansk
# Processing Record 13 of Set 21 | ostrovnoy
# Ostrovnoy
# Processing Record 14 of Set 21 | kargasok
# Kargasok
# Processing Record 15 of Set 21 | druzhba
# Druzhba
# Processing Record 16 of Set 21 | bulgan
# Bulgan
# Processing Record 17 of Set 21 | pemangkat
# Pemangkat
# Processing Record 18 of Set 21 | talnakh
# Talnakh
# Processing Record 19 of Set 21 | dakoro
# Dakoro
# Processing Record 20 of Set 21 | port lincoln
# Port Lincoln
# Processing Record 21 of Set 21 | adrar
# Adrar
# Processing Record 22 of Set 21 | rabak
# Rabak
# Processing Record 23 of Set 21 | naifaru
# Naifaru
# Processing Record 24 of Set 21 | nuuk
# Nuuk
# Processing Record 25 of Set 21 | morondava
# Morondava
# Processing Record 26 of Set 21 | ustye
# Ust'ye
# Processing Record 27 of Set 21 | urubicha
# Urubichá
# Processing Record 28 of Set 21 | tulum
# Tulum
# Processing Record 29 of Set 21 | san carlos de bariloche
# Bariloche
# Processing Record 30 of Set 21 | placerville
# Placerville
# Processing Record 31 of Set 21 | taltal
# Taltal
# Processing Record 32 of Set 21 | chuy
# Chui
# Processing Record 33 of Set 21 | rocha
# Rocha
# Processing Record 34 of Set 21 | komsomolskiy
# Yangi Marg`ilon
# Processing Record 35 of Set 21 | havre-saint-pierre
# Havre-St-Pierre
# Processing Record 36 of Set 21 | constitucion
# Constitución
# Processing Record 37 of Set 21 | nautla
# Nautla
# Processing Record 38 of Set 21 | kamenskiy
# Kamenskiy
# Processing Record 39 of Set 21 | chagoda
# Chagoda
# Processing Record 40 of Set 21 | hami
# Kumul
# Processing Record 41 of Set 21 | kajaani
# Kajaani
# Processing Record 42 of Set 21 | auki
# Auki
# Processing Record 43 of Set 21 | mindelo
# Mindelo
# Processing Record 44 of Set 21 | mandalgovi
# Mandalgovi
# Processing Record 45 of Set 21 | ust-nera
# Ust-Nera
# Processing Record 46 of Set 21 | belyy yar
# Belyy Yar
# Processing Record 47 of Set 21 | aksakovo
# Aksakovo Municipality
# Processing Record 48 of Set 21 | kemijarvi
# Kemijärvi
# Processing Record 49 of Set 21 | lyndon
# Lyndon
# Processing Record 50 of Set 21 | aykhal
# Aykhal
# Processing Record 1 of Set 22 | kloulklubed
# Kloulklubed
# Processing Record 2 of Set 22 | seymchan
# Seymchan
# Processing Record 3 of Set 22 | porto novo
# Porto-Novo
# Processing Record 4 of Set 22 | fortuna
# Fortuna
# Processing Record 5 of Set 22 | lebu
# Lebu
# Processing Record 6 of Set 22 | daru
# Daru
# Processing Record 7 of Set 22 | tocopilla
# Tocopilla
# Processing Record 8 of Set 22 | sola
# Sola
# Processing Record 9 of Set 22 | ambulu
# Ambulu
# Processing Record 10 of Set 22 | myatlevo
# Myatlevo
# Processing Record 11 of Set 22 | arbazh
# Arbazh
# Processing Record 12 of Set 22 | egvekinot
# Egvekinot
# Processing Record 13 of Set 22 | samaro
# Samaro
# Processing Record 14 of Set 22 | srednekolymsk
# Srednekolymsk
# Processing Record 15 of Set 22 | mogadishu
# Mogadishu
# Processing Record 16 of Set 22 | fairbanks
# Fairbanks
# Processing Record 17 of Set 22 | krasnyy chikoy
# Krasnyy Chikoy
# Processing Record 18 of Set 22 | oranjemund
# Oranjemund
# Processing Record 19 of Set 22 | bilibino
# Bilibino
# Processing Record 20 of Set 22 | eureka
# Eureka
# Processing Record 21 of Set 22 | acapulco
# Acapulco de Juárez
# Processing Record 22 of Set 22 | homer
# Homer
# Processing Record 23 of Set 22 | sorland
# Sørland
# Processing Record 24 of Set 22 | sakakah
# Sakakah
# Processing Record 25 of Set 22 | villa bruzual
# Villa Bruzual
# Processing Record 26 of Set 22 | solnechnyy
# Solnechnyy
# Processing Record 27 of Set 22 | slave lake
# Slave Lake
# Processing Record 28 of Set 22 | darhan
# Darhan
# Processing Record 29 of Set 22 | kulhudhuffushi
# Kulhudhuffushi
# Processing Record 30 of Set 22 | camana
# Camaná
# Processing Record 31 of Set 22 | saint-malo
# Arrondissement de Saint-Malo
# Processing Record 32 of Set 22 | alpena
# Alpena
# Processing Record 33 of Set 22 | lorengau
# Lorengau
# Processing Record 34 of Set 22 | nikel
# Nikel
# Processing Record 35 of Set 22 | kapuskasing
# Kapuskasing
# Processing Record 36 of Set 22 | fort nelson
# Fort Nelson
# Processing Record 37 of Set 22 | kaeo
# Kaeo
# Processing Record 38 of Set 22 | bubaque
# Bubaque
# Processing Record 39 of Set 22 | shakiso
# Shakiso
# Processing Record 40 of Set 22 | buraydah
# Buraidah
# Processing Record 41 of Set 22 | gananoque
# Gananoque
# Processing Record 42 of Set 22 | axim
# Esim
# Processing Record 43 of Set 22 | ibra
# Ibrā’
# Processing Record 44 of Set 22 | klaksvik
# Klaksvík
# Processing Record 45 of Set 22 | erzin
# Erzin
# Processing Record 46 of Set 22 | simnas
# Simnas
# Processing Record 47 of Set 22 | beringovskiy
# Beringovskiy
# Processing Record 48 of Set 22 | rorvik
# Rørvik
# Processing Record 49 of Set 22 | bom jesus
# Bom Jesus
# Processing Record 50 of Set 22 | ongandjera
# Ongandjera
# Processing Record 1 of Set 23 | sosnovskiy
# city not found
# Processing Record 2 of Set 23 | abnub
# Abnūb
# Processing Record 3 of Set 23 | ocampo
# Ocampo
# Processing Record 4 of Set 23 | inirida
# Inírida
# Processing Record 5 of Set 23 | goderich
# Goderich
# Processing Record 6 of Set 23 | olinda
# Olinda
# Processing Record 7 of Set 23 | namibe
# Mossamedes
# Processing Record 8 of Set 23 | kristiansund
# Kristiansund
# Processing Record 9 of Set 23 | yirol
# city not found
# Processing Record 10 of Set 23 | kuche
# city not found
# Processing Record 11 of Set 23 | dafeng
# Dafeng
# Processing Record 12 of Set 23 | holme
# Holme
# Processing Record 13 of Set 23 | oum hadjer
# Umm Hājar
# Processing Record 14 of Set 23 | cayenne
# Cayenne
# Processing Record 15 of Set 23 | mahanoro
# Mahanoro
# Processing Record 16 of Set 23 | kinkala
# Kinkala
# Processing Record 17 of Set 23 | phan thiet
# Phan Thiet
# Processing Record 18 of Set 23 | tabora
# Tabora
# Processing Record 19 of Set 23 | kelvington
# Kelvington
# Processing Record 20 of Set 23 | kapit
# Kapit
# Processing Record 21 of Set 23 | cayambe
# Cayambe
# Processing Record 22 of Set 23 | tarko-sale
# Tarko-Sale
# Processing Record 23 of Set 23 | karaul
# city not found
# Processing Record 24 of Set 23 | lazaro cardenas
# Lázaro Cárdenas
# Processing Record 25 of Set 23 | taree
# Taree
# Processing Record 26 of Set 23 | hasaki
# Hasaki
# Processing Record 27 of Set 23 | kutum
# Kutum
# Processing Record 28 of Set 23 | saint anthony
# Saint Anthony
# Processing Record 29 of Set 23 | deniliquin
# Deniliquin
# Processing Record 30 of Set 23 | saurimo
# Saurimo
# Processing Record 31 of Set 23 | miami
# Miami
# Processing Record 32 of Set 23 | bayshore gardens
# Bayshore Gardens
# Processing Record 33 of Set 23 | kuusamo
# Kuusamo
# Processing Record 34 of Set 23 | brae
# Brae
# Processing Record 35 of Set 23 | lolua
# city not found
# Processing Record 36 of Set 23 | ntchisi
# Ntchisi
# Processing Record 37 of Set 23 | tanout
# Tanout
# Processing Record 38 of Set 23 | flinders
# Flinders
# Processing Record 39 of Set 23 | haines junction
# Haines Junction
# Processing Record 40 of Set 23 | valenca
# Valença
# Processing Record 41 of Set 23 | sambava
# Sambava
# Processing Record 42 of Set 23 | loanda
# Luanda
# Processing Record 43 of Set 23 | bosaso
# Bosaso
# Processing Record 44 of Set 23 | jiroft
# city not found
# Processing Record 45 of Set 23 | port shepstone
# Port Shepstone
# Processing Record 46 of Set 23 | nyurba
# Nyurba
# Processing Record 47 of Set 23 | sao joao dos patos
# São João dos Patos
# Processing Record 48 of Set 23 | santa isabel
# Santa Isabel
# Processing Record 49 of Set 23 | ishim
# Ishim
# Processing Record 50 of Set 23 | ascension
# Ascension
# Processing Record 1 of Set 24 | praia da vitoria
# Praia da Vitória
# Processing Record 2 of Set 24 | kez
# Kez
# Processing Record 3 of Set 24 | beberibe
# Beberibe
# Processing Record 4 of Set 24 | esperantina
# Esperantina
# Processing Record 5 of Set 24 | umzimvubu
# city not found
# Processing Record 6 of Set 24 | tucurui
# Tucuruí
# Processing Record 7 of Set 24 | mahadday weyne
# city not found
# Processing Record 8 of Set 24 | sergeyevka
# Sergeevka
# Processing Record 9 of Set 24 | port arthur
# Lüshunkou
# Processing Record 10 of Set 24 | shingu
# Shingū
# Processing Record 11 of Set 24 | barcelona
# Barcelona
# Processing Record 12 of Set 24 | port moresby
# Port Moresby
# Processing Record 13 of Set 24 | obihiro
# Obihiro
# Processing Record 14 of Set 24 | richards bay
# Richards Bay
# Processing Record 15 of Set 24 | waimana
# Waimana
# Processing Record 16 of Set 24 | samarai
# Samarai
# Processing Record 17 of Set 24 | diffa
# Diffa
# Processing Record 18 of Set 24 | yar-sale
# Yar-Sale
# Processing Record 19 of Set 24 | molteno
# Molteno
# Processing Record 20 of Set 24 | sinnamary
# Sinnamary
# Processing Record 21 of Set 24 | acarau
# Acaraú
# Processing Record 22 of Set 24 | lincoln
# Lincoln
# Processing Record 23 of Set 24 | may pen
# May Pen
# Processing Record 24 of Set 24 | nishihara
# Nishihara
# Processing Record 25 of Set 24 | waddan
# Waddān
# Processing Record 26 of Set 24 | santa marta
# Santa Marta
# Processing Record 27 of Set 24 | ugento
# Ugento
# Processing Record 28 of Set 24 | araouane
# Araouane
# Processing Record 29 of Set 24 | bartica
# Bartica
# Processing Record 30 of Set 24 | storm lake
# Storm Lake
# Processing Record 31 of Set 24 | yulara
# Yulara
# Processing Record 32 of Set 24 | bowen
# Bowen
# Processing Record 33 of Set 24 | henties bay
# Henties Bay
# Processing Record 34 of Set 24 | norman wells
# Norman Wells
# Processing Record 35 of Set 24 | brownwood
# Brownwood
# Processing Record 36 of Set 24 | phuket
# Phuket
# Processing Record 37 of Set 24 | eseka
# Eséka
# Processing Record 38 of Set 24 | nioki
# Nioki
# Processing Record 39 of Set 24 | barra do garcas
# Barra do Garças
# Processing Record 40 of Set 24 | ziyang
# Ziyang
# Processing Record 41 of Set 24 | pavilosta
# Pāvilosta
# Processing Record 42 of Set 24 | tuta
# Tuta
# Processing Record 43 of Set 24 | perundurai
# Perundurai
# Processing Record 44 of Set 24 | cherskiy
# Cherskiy
# Processing Record 45 of Set 24 | guerrero negro
# Guerrero Negro
# Processing Record 46 of Set 24 | marzuq
# Marzuq
# Processing Record 47 of Set 24 | mudon
# Mudon
# Processing Record 48 of Set 24 | pinega
# Pinega
# Processing Record 49 of Set 24 | ananindeua
# Ananindeua
# Processing Record 50 of Set 24 | klyuchi
# Klyuchi
# Processing Record 1 of Set 25 | vicksburg
# Vicksburg
# Processing Record 2 of Set 25 | acuna
# city not found
# Processing Record 3 of Set 25 | rosarito
# Rosarito
# Processing Record 4 of Set 25 | muros
# Muros
# Processing Record 5 of Set 25 | ust-tsilma
# Ust-Tsilma
# Processing Record 6 of Set 25 | saint george
# Saint George
# Processing Record 7 of Set 25 | batemans bay
# Batemans Bay
# Processing Record 8 of Set 25 | port angeles
# Port Angeles
# Processing Record 9 of Set 25 | charlottesville
# Charlottesville
# Processing Record 10 of Set 25 | cao bang
# Cao Bang
# Processing Record 11 of Set 25 | meulaboh
# Meulaboh
# Processing Record 12 of Set 25 | mizdah
# Mizdah
# Processing Record 13 of Set 25 | udachnyy
# Udachny
# Processing Record 14 of Set 25 | addis zemen
# city not found
# Processing Record 15 of Set 25 | estelle
# Estelle
# Processing Record 16 of Set 25 | macenta
# Macenta
# Processing Record 17 of Set 25 | morden
# Morden
# Processing Record 18 of Set 25 | maningrida
# Maningrida
# Processing Record 19 of Set 25 | altay
# Altay
# Processing Record 20 of Set 25 | sale
# Salé
# Processing Record 21 of Set 25 | beruwala
# Beruwala
# Processing Record 22 of Set 25 | laurel
# Laurel
# Processing Record 23 of Set 25 | shar
# Shar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                  City Country    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# 0     Tsiroanomandidy      MG -18.77  46.03     59.50        79           0
# 1          Nikolskoye      RU  59.70  30.79     62.60        72          40
# 2       Dzerzhinskoye      RU  56.83  95.23     68.77        75          98
# 3              Vieste      IT  41.88  16.18     75.00        68          20
# 4          Kormilovka      RU  55.00  74.10     51.80        93          75
# ...               ...     ...    ...    ...       ...       ...         ...
# 1149            Altay      CN  47.87  88.12     67.86        40          59
# 1150             Sale      MA  34.04  -6.82     70.00        93          40
# 1151         Beruwala      LK   6.48  79.98     80.91        82          56
# 1152           Laurel      US  39.10 -76.85     84.00        69          40
# 1153             Shar      KZ  49.59  81.05     57.96        44          29
#
#       Wind Speed          Current Description  Rain (inches)  Snow (inches)
# 0           2.80                    clear sky            0.0            0.0
# 1           5.08                 thunderstorm            0.0            0.0
# 2           1.92              overcast clouds            0.0            0.0
# 3           5.82                   few clouds            0.0            0.0
# 4          15.66  light intensity shower rain            0.0            0.0
# ...          ...                          ...            ...            ...
# 1149        6.15                broken clouds            0.0            0.0
# 1150        5.82             scattered clouds            0.0            0.0
# 1151        9.31                broken clouds            0.0            0.0
# 1152       11.97             scattered clouds            0.0            0.0
# 1153        9.48             scattered clouds            0.0            0.0
#
# [1154 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
