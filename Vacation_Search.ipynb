# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
#File to load
weather_data_to_load = "weather_data/WeatherPy_database.csv"

# %%
# Read the   file and store it in a pandas DataFrame.
weather_data_df = pd.read_csv( weather_data_to_load)
weather_data_df.head(10)
# Out:
#    Unnamed: 0             City Country    Lat     Lng  Max Temp  Humidity  \
# 0           0  Tsiroanomandidy      MG -18.77   46.03     59.50        79
# 1           1       Nikolskoye      RU  59.70   30.79     62.60        72
# 2           2    Dzerzhinskoye      RU  56.83   95.23     68.77        75
# 3           3           Vieste      IT  41.88   16.18     75.00        68
# 4           4       Kormilovka      RU  55.00   74.10     51.80        93
# 5           5        Inhambane      MZ -23.86   35.38     67.95        71
# 6           6           Hobart      AU -42.88  147.33     41.00        86
# 7           7             Hofn      IS  64.25  -15.21     54.27        84
# 8           8         Thompson      CA  55.74  -97.86     62.60        93
# 9           9           Atuona      PF  -9.80 -139.03     80.44        74
#
#    Cloudiness  Wind Speed          Current Description  Rain (inches)  \
# 0           0        2.80                    clear sky            0.0
# ...

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
raining = input("Do you want it to be raining? (yes/no) ")
snowing = input("Do you want it to be snowing? (yes/no)")
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 95
# Do you want it to be raining? (yes/no) no
# Do you want it to be snowing? (yes/no)no

# %%
# Filter the dataset to find the cities that fit the criteria.
# preferred_cities_df = weather_data_df.loc[(weather_data_df["Max Temp"] <= max_temp) & \
#                                        (weather_data_df["Max Temp"] >= min_temp) & \
if raining == "no" and snowing == "no":
    preferred_cities_df = weather_data_df.loc[(weather_data_df["Max Temp"] <= max_temp) & \
                                             (weather_data_df["Max Temp"] >= min_temp) & \
                                             (weather_data_df["Rain (inches)"] == 0) & \
                                             (weather_data_df["Snow (inches)"] == 0)]
    
elif raining == "no" and snowing == "yes":
    preferred_cities_df = weather_data_df.loc[(weather_data_df["Max Temp"] <= max_temp) & \
                                             (weather_data_df["Max Temp"] >= min_temp) & \
                                             (weather_data_df["Rain (inches)"] == 0) & \
                                             (weather_data_df["Snow (inches)"] > 0)]
    
elif raining == "yes" and snowing == "no":
    preferred_cities_df = weather_data_df.loc[(weather_data_df["Max Temp"] <= max_temp) & \
                                             (weather_data_df["Max Temp"] >= min_temp) & \
                                             (weather_data_df["Rain (inches)"] > 0) & \
                                             (weather_data_df["Snow (inches)"] == 0)]
    
else:
    preferred_cities_df = weather_data_df.loc[(weather_data_df["Max Temp"] <= max_temp) & \
                                             (weather_data_df["Max Temp"] >= min_temp) & \
                                             (weather_data_df["Rain (inches)"] > 0) & \
                                             (weather_data_df["Snow (inches)"] > 0)]
                                                             
preferred_cities_df.head(10)
# Out:
#     Unnamed: 0                 City Country    Lat     Lng  Max Temp  \
# 3            3               Vieste      IT  41.88   16.18     75.00
# 9            9               Atuona      PF  -9.80 -139.03     80.44
# 11          11              Kahului      US  20.89 -156.47     87.80
# 15          15              Rikitea      PF -23.12 -134.97     70.25
# 19          19         Puerto Ayora      EC  -0.74  -90.35     71.01
# 22          22                  Gat      IL  31.61   34.76     72.00
# 23          23          Yellowknife      CA  62.46 -114.35     72.00
# 24          24  Rancho Palos Verdes      US  33.74 -118.39     73.00
# 26          26         Ponta Do Sol      PT  32.67  -17.10     71.60
# 31          31                Sembe      CG   1.65   14.58     70.34
#
#     Humidity  Cloudiness  Wind Speed Current Description  Rain (inches)  \
# 3         68          20        5.82          few clouds            0.0
# ...

# %%
preferred_cities_df.count()
# Out:
# Unnamed: 0             496
# City                   496
# Country                496
# Lat                    496
# Lng                    496
# Max Temp               496
# Humidity               496
# Cloudiness             496
# Wind Speed             496
# Current Description    496
# Rain (inches)          496
# Snow (inches)          496
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Current Description", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                    City Country Current Description  Max Temp    Lat     Lng  \
# 3                Vieste      IT          few clouds     75.00  41.88   16.18
# 9                Atuona      PF    scattered clouds     80.44  -9.80 -139.03
# 11              Kahului      US          few clouds     87.80  20.89 -156.47
# 15              Rikitea      PF           clear sky     70.25 -23.12 -134.97
# 19         Puerto Ayora      EC       broken clouds     71.01  -0.74  -90.35
# 22                  Gat      IL           clear sky     72.00  31.61   34.76
# 23          Yellowknife      CA       broken clouds     72.00  62.46 -114.35
# 24  Rancho Palos Verdes      US          few clouds     73.00  33.74 -118.39
# 26         Ponta Do Sol      PT          few clouds     71.60  32.67  -17.10
# 31                Sembe      CG     overcast clouds     70.34   1.65   14.58
#
#    Hotel Name
# 3
# 9
# 11
# 15
# 19
# 22
# 23
# 24
# 26
# 31

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
hotel_df.to_csv(output_data_file)

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print(hotels)
# Out:
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# ...

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig

#gmaps.savefig("weather_data/WeatherPy_vaction_map.png")
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
hotel_df.to_csv(output_data_file)
